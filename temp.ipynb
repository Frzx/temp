# %%
from PIL import Image

# %%
image = Image.open("input_image.png")

# %%
box = [
        72.98080444335938,
        2092.75341796875,
        520.8131103515625,
        2206.5859375
      ]
image.crop(box)
# Out:
# <PIL.Image.Image image mode=RGB size=448x114>
